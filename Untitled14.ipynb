# %%
import numpy as np
import pandas as pd
from datascience import *
from  google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/spam.csv')

# %%
df
# Out:
#     Area Code
# 0         891
# 1         924
# 2         516
# 3         512
# 4         328
# 5         613
# 6         214
# 7         940
# 8         591
# 9         950
# 10        509
# 11        762
# 12        909
# 13        420
# 14        424
# 15        763
# 16        659
# 17        442
# 18        313
# 19        212
# 20        376
# 21        539
# 22        242
# 23        655
# 24        770
# 25        630
# 26        385
# 27        303
# 28        549
# 29        555
# 30        993
# 31        297
# 32        262
# 33        827
# 34        642
# 35        403
# 36        833
# 37        433
# 38        710
# 39        652
# 40        558
# 41        716
# 42        911
# 43        940
# 44        603
# 45        535
# 46        236
# 47        678
# 48        429
# 49        578

# %%
probability_ravi = (1/940) **2
probability_ravi
# Out:
# 1.1317338162064282e-06

# %%
probability_num = (1/9) **7
probability_num
# Out:
# 2.090751581287689e-07

# %%
spammers_number = Table().read_table('/content/drive/My Drive/Colab Notebooks/spam.csv')
spammers_number
# Out:
# Area Code
# 891
# 924
# 516
# 512
# 328
# 613
# 214
# 940
# 591
# 950
# ... (40 rows omitted)

# %%
reasonable_statistics_test = make_array(1,4,5)

# %%
set(reasonable_statistics_test) == set([1,4,5])
# Out:
# True

# %%
model_proportions = make_array(0.01,0.99)

def simulate():
    return(50*sample_proportions(50,model_proportions).item(0))

simulate()
# Out:
# 1.0

# %%
visited_test_statistics_under_null = make_array()
repetitions = 20000

for i in np.arange(repetitions):
    new_num_of_correct_area_code = simulate()
    visited_test_statistics_under_null = np.append(visited_test_statistics_under_null,new_num_of_correct_area_code)
    
    
visited_test_statistics_under_null
# Out:
# array([ 1.,  1.,  1., ...,  0.,  1.,  1.])

# %%
len(visited_test_statistics_under_null) == 20000
# Out:
# True

# %%
import matplotlib.pyplot as plt

x = visited_test_statistics_under_null
num_bins = np.arange(0, 5, 1)

n, bins, patches = plt.hist(x, num_bins, facecolor = 'blue', alpha = 0.75, edgecolor = 'black')

plt.title('Hist')
plt.show()
