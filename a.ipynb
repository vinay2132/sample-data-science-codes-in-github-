# %%
b=input('enter the char:')
a=ord(b)
print(a)
if (a>=97 and a<=122) or (a>=65 and a<=90):
    print('char')
else:
    print('specal')
if a>=97 and a<=122:
    print('lower case')
elif a>=5 and a<=90:
    print('upper case')
else:
    print ('special')
# Out:
# enter the char:a
# 97
# char
# lower case

# %%
print (name)
# Out:
# viany
