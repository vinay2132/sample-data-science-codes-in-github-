# %% [markdown]
# **Yield** is a keyword in Python that is used to return from a function without destroying the states of its local variable and when the function is called, the execution starts from the last yield statement. Any function that contains a yield keyword is termed a generator. Hence, yield is what makes a generator. The yield keyword in Python is less known off but has a greater utility which one can think of.

# %%
def nextSquare():
    i = 1
 
    # An Infinite loop to generate squares
    while True:
        yield i*i                
        i += 1 # Next execution resumes
                # from this point    
 
# Driver code
for num in nextSquare():
    if num > 100:
        break   
    print(num)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# list to string can be easily converted using join opoeration and also can be done by using for loop where they can be used store the string in an varibel called str1 by itterating with the for loop

# %%
a = ['a','b','c','d','f']
strin = ' '.join(a)
print(strin)
# way 2 by using for loop
str1 = ""
for x in a:
  str1 += x
print(str1)
# Out:
# a b c d f
# abcdf

# %% [markdown]
# converting list into tuple can be done by directly writing tupple in the front of the list which conversts it into tuple

# %%
#converting list to tuple

tup = tuple(a)
print(tup)
# Out:
# ('a', 'b', 'c', 'd', 'f')

# %% [markdown]
# converting an list to set by using directly writing set at the begining of the thing

# %%
sets = set(a)
print(sets)
# Out:
# {'c', 'd', 'f', 'b', 'a'}

# %% [markdown]
# counting of particular elements itterated in the list by directing writing count and the required element to search or acan also be doen by using for an dif loop

# %%
a = ['a','b','c','d','f','a','c','a','a']
print(a.count('a'))
#methord 2
count = 0
for i in a:
  if i == 'a':
    count +=1
print(count)
# Out:
# 4
# 4

# %% [markdown]
# Numpy array: A numpy array is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers. The number of dimensions is the rank of the array; the shape of an array is a tuple of integers giving the size of the array along each dimension. and we can create empty numpy array by using this

# %%
import numpy as np
print(np.array([]))
a =np.array([])
print(a)
# Out:
# []
# []

# %% [markdown]
# The **negative index** is used to remove any new-line spaces from the string and allow the string to except the last character that is given as S[:-1]. The negative index is also used to show the index to represent the string in correct order.

# %%
a =[1,2,3,4,'']
print(a[-4])
print(a[-1])
print(a[0])
# Out:
# 2
#
# 1

# %%
a=['abc','bcd','cde']
print(a[-1][-2])
# Out:
# d

# %% [markdown]
# Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object. This enumerated object can then be used directly for loops or converted into a list of tuples using the list() method.

# %%
l1 = ["eat","sleep","repeat"]
s1 = "geek"
 
# creating enumerate objects
obj1 = enumerate(l1)
obj2 = enumerate(s1)
 
print ("Return type:",type(obj1))
print (list(enumerate(l1)))
 
# changing start index to 2 from 0
print (list(enumerate(s1,2)))
# Out:
# Return type: <class 'enumerate'>
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]
# [(2, 'g'), (3, 'e'), (4, 'e'), (5, 'k')]

# %%
l1 = ["eat","sleep","repeat"]

obj1 = enumerate(l1)

print (list(enumerate(l1)))
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %% [markdown]
# Sets are used to store multiple items in a single variable.A set is a collection which is both unordered and unindexed.Set items are unordered, unchangeable, and do not allow duplicate values.

# %% [markdown]
# Concatenate Strings in Python is basically done by uisng simple +operation

# %%
print('a'+'b'+'c')
# Out:
# abc

# %% [markdown]
# we can generate numbers randomly in python by:
# random() – This command returns a floating point number, between 0 and 1.
#
# 2. uniform(X, Y) – It returns a floating point number between the values given as X and Y.
#
# 3. randint(X, Y) – This command returns a random integer between the values given as X and Y.

# %%
import random

print(random.randint(0,9))
print(random.uniform(0,9))
# Out:
# 7
# 0.19969499102258148

# %%
#printing sum of number from one to 100
#print sum(range(1,101))

i=1
sum = 0

for i in range (1,101):
  sum+=i
print(sum)
# Out:
# 5050

# %% [markdown]
# Global keyword is a keyword that allows a user to modify a variable outside of the current scope. It is used to create global variables from a non-global scope i.e inside a function. Global keyword is used inside a function only when we want to do assignments or when we want to change a variable. Global is not needed for printing and accessing.

# %%
a = 15
b = 10
  

def add():
    c = a + b
    print(c)
  

add()
# Out:
# 25

# %%
names1 = ['Amir', 'Bear', 'Charlton', 'Daman']
names2 = names1
names3 = names1[:]

names2[0] = 'Alice'
names3[1] = 'Bob'

sum = 0

for ls in (names1, names2, names3):
  if ls[0] == 'Alice':
    sum += 1
  if ls[1] == 'Bob':
    sum += 10
print (sum)
# Out:
# 12

# %%
#avg of num of in an list
from statistics import mean

def Average(lst):
	return mean(lst)

# Driver Code
lst = [15, 9, 55, 41, 35, 20, 62, 49]
average = Average(lst)

# Printing average of the list
print("Average of the list =", round(average, 2))
# Out:
# Average of the list = 35.75

# %%
#reverse of an number and sum of digits and palandrome and numb of digets 
a = int(input())
rev = 0
tot = 0
temp = a
count = 0
while(a>0):
  dig = a%10
  rev = rev*10+dig
  #sum of numbers
  tot += dig
  count+= 1
  a = a//10
#palandrom or not
if(temp == a):
  print("pala")
else:
  print("not")
print(rev,tot,count)
# Out:
# 123345621
# not
# 126543321 27 9

# %%
#print number table
a = int(input())
for i in range (1,11):
  print(a,"x",i,"=",a*i)
# Out:
# 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
#chaeck if the number is prime or not
num = int(input())
 

if num > 1:
 
    
    for i in range(2, int(num/2)+1):
 
       
        if (num % i) == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
 
else:
    print(num, "is not a prime number")
# Out:
# 11
# 11 is a prime number

# %%
#Armstrong  number

num = int(input("Enter a number: "))


sum = 0


temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10


if num == sum:
   print(" Armstrong")
else:
   print(" not ")
# Out:
# Enter a number: 145
#  not

# %%
#perfect number

n = int(input())
sum = 0
if(n%i ==0 ):
  sum+=i
if(sum == n):
  print("perfect")
else:
  print("not")
# Out:
# 12233
# not

# %%
#strong number or not
sum1=0
num=int(input("Enter a number:"))
temp=num
while(num):
  i=1
  f=1
  r=num%10
  while(i<=r):
    f=f*i
  i=i+1
  sum1=sum1+f
  num=num//10
if(sum1==temp):
  print("The number is a strong number")
else:
  print("The number is not a strong number")

# %%
# secount largest number in the list
a=[]
n=int(input("Enter number of elements:"))
for i in range(1,n+1):
  b=int(input("Enter element:"))
  a.append(b)
a.sort()
1
print("Second largest element is:",a[-2])
# Out:
# Enter number of elements:4
# Enter element:1
# Enter element:3
# Enter element:5
# Enter element:7
# Second largest element is: 5

# %%
#swap first ans last numbers in the list
a=[]
n= int(input("Enter the number of elements in list:"))
for x in range(0,n):
  element=int(input("Enter element" + str(x+1) + ":"))
  a.append(element)
temp=a[0]
a[0]=a[n-1]
a[n-1]=temp
print("New list is:")
print(a)
# Out:
# Enter the number of elements in list:4
# Enter element1:1
# Enter element2:4
# Enter element3:5
# Enter element4:6
# New list is:
# [6, 4, 5, 1]

# %%
#Count the Number of Vowels in a String
string=str(input())
vowels=0
for i in string:
  if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u' or i=='A' or i=='E' or i=='I' or i=='O' or i=='U'):
    vowels=vowels+1

print(vowels)
# Out:
# abcdef
# 2

# %%
#Common Letters in Two Input Strings
s1=str(input("first"))
s2=str(input("second"))
a=list(set(s1)&set(s2))

for i in a:
  print(i)
# Out:
# firstabcdef
# secondabcdefgg
# c
# d
# f
# b
# e
# a
