# %% [markdown]
# <span style='background:yellow'>**Question 1.1.1.**</span> This paragraph is in its own text cell.  Try editing it so that this sentence is the last sentence in the paragraph, and then click the "run cell" ▶| button or hold down `shift` + `return`.  This sentence, for example, should be deleted.  So should this one.

# %% [markdown]
# Ans:
# <span style='background:yellow'>**Question 1.1.1.**</span> This paragraph is in its own text cell.  Try editing it so that this sentence is the last sentence in the paragraph, and then click the "run cell" ▶| button or hold down `shift` + `return`.

# %% [markdown]
# <span style='background:yellow'>**Question 1.2.1.**</span> Change the cell above so that it prints out:
#
#     First this line,
#     then the whole 🌏,
#     and then this one.
#
# *Hint:* If you're stuck on the Earth symbol for more than a few minutes, try talking to a neighbor or a staff member (the instructor or the TA). That's a good idea for any lab problem.

# %% [markdown]
# Ans:

# %%
print("First this line,\nthen the whole 🌏,\nand then this one.");
# Out:
# First this line,
# then the whole 🌏,
# and then this one.

# %% [markdown]
# <span style='background:yellow'>**Question 1.3.1.**</span> Add a code cell below this one.  Write code in it that prints out:
#
#     A whole new cell! ♪🌏♪
#
# (That musical note symbol is like the Earth symbol.  Its long-form name is `\N{EIGHTH NOTE}`.)
#
# Run your cell to verify that it works.

# %% [markdown]
# Ans:

# %%
print("A whole new cell! ♪🌏♪")
# Out:
# A whole new cell! ♪🌏♪

# %% [markdown]
# <span style='background:yellow'>**Question 3.1.**</span> Try writing code that uses a name (like `eleven`) that hasn't been assigned to anything.  You'll see an error!

# %% [markdown]
# Ans:

# %%
#since eleven was not defined it throws' an error
eleven =11
eleven
# Out:
# 11

# %% [markdown]
# <span style='background:yellow'>**Question 4.1.1.**</span> Fill in the line `num_avenues_away = ...` in the next cell so that the cell calculates the distance Chunhua must walk and gives it the name `manhattan_distance`.  Everything else has been filled in for you.  **Use the `abs` function.**

# %%
# Here's the number of streets away:
num_streets_away = abs(42-34)

# Compute the number of avenues away in a similar way:
# num_avenues_away = ...

street_length_m = 80
avenue_length_m = 274

# Now we compute the total distance Chunhua must walk.
# manhattan_distance = street_length_m*num_streets_away + avenue_length_m*num_avenues_away

# We've included this line so that you see the distance you've computed 
# when you run this cell.  
# You don't need to change it, but you can if you want.
# manhattan_distance

# %% [markdown]
# Ans:

# %%
num_avenues_away = 3

# %%
num_streets_away = abs(42-34)

street_length_m = 80
avenue_length_m = 274

manhattan_distance = street_length_m*num_streets_away + avenue_length_m*num_avenues_away

manhattan_distance
# Out:
# -182

# %%
num_avenues_away = -3

# %%
num_streets_away = abs(42-34)

street_length_m = 80
avenue_length_m = 274

manhattan_distance = street_length_m*num_streets_away + avenue_length_m*num_avenues_away

manhattan_distance
# Out:
# 1462

# %% [markdown]
# <span style='background:yellow'>**Question 3.3.1. && Question 3.3.2.**</span> Complete the code in the next cell to fill in the data from the experiment.
#
# *Hint:* No computation required; just fill in data from the paragraph above.

# %%
time = 1.2 
estimated_distance_m = 1.13

# %%
gravity_constant = 6.674 * 10**-11
moon_mass_kg = 7.34767309 * 10**22
moon_radius_m = 1.737 * 10**6
print(gravity_constant,moon_mass_kg,moon_radius_m)

#0.5*(gravity_constant*(moon_mass_kg/(moon_radius_m**2))*time**2)
# Out:
# 6.674e-11 7.34767309e+22 1737000.0

# %%
predicted_distance_m = 0.5*(gravity_constant*(moon_mass_kg/(moon_radius_m**2))*time**2)
predicted_distance_m
# Out:
# 1.1702236946593048

# %%
difference = predicted_distance_m - estimated_distance_m
abs(difference)
# Out:
# 0.040223694659304865

# %% [markdown]
# <span style='background:yellow'>**Question 5.1. && Question 5.1.1**</span> Say that Paola's height is 1.76 meters.  In the next cell, use `abs` to compute the absolute value of the difference between Paola's height and the average human height.  Give that value the name `paola_distance_from_average_m`.

# %% [markdown]
# Ans :

# %%
paola_distance_from_average_m = abs(1.76-1.688)
paola_distance_from_average_m
# Out:
# 0.07200000000000006

# %%
round(paola_distance_from_average_m, 5)
# Out:
# 0.072
