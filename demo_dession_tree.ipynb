# %% [markdown]
# eduraka ml video class for dession tree algo

# %%
training_data = [
                 ['green',3,'mango'],
                 ['yellow',3,'mango'],
                 ['red',1,'grape'],
                 ['red',1,'grape'],
                 ['yellow',3,'lemon'],
]
header = ["colour","diameter","lable"]

# %%
def class_counts(rows):
  counts = {}
  for row in rows:
    lable = row[-1]
    if lable not in counts:
      counts[label] = 0
    counts[label] +=1
  return counts

# %%
def is_numeric(value):
  return  isinstance(value,int) or isinstance(value,float)

# %%
class Question:
  def __init__(self , column , value):
    self.column = column
    self.value = value
  def match(self, example):
    val = example[self]
    if is_numeric(val):
      return val >= self.value
    else:
      return val == self.value
  def __repr__(self):
    condition = "=="
    if is_numeric(self,value):
      condition = ">="
    return "Is %s %s %s?" %(
        header[self.column],condition,str(self.value)
    )
  def partition(row,question):
    true_rows,false_rows = [],[]
    for row in rows:
      if question.append(row):
        true_rows.append(row)
      else:
        false_rows.apped(row)
    return true_rows,false_rows
