# %%
from sympy import *
init_printing(use_latex = True)

# %%
var('x')
var('y')
func1 = 6*(x**2)+x*y+6*(y**2)
solve([diff(func1,x),diff(func1,y)],(x,y))
# Out:
# {x: 0, y: 0}

# %%
from sympy.vector import gradient,CoordSys3D
R = CoordSys3D('R')
func2 = 5*R.x*(exp(R.x*R.y)) + R.x*R.y+R.z
gradient(func2)
# Out:
# ⎛           x_R⋅y_R            x_R⋅y_R⎞        ⎛     2  x_R⋅y_R      ⎞
# ⎝5⋅x_R⋅y_R⋅ℯ        + y_R + 5⋅ℯ       ⎠ i_R  + ⎝5⋅x_R ⋅ℯ        + x_R⎠ j_R  +
#
#
# k_R
