# %%
import pywhatkit
pywhatkit.sendwhatmsg('+918919194468', '...', 6, 6)
# Out:
#   File "<ipython-input-3-47df823531bb>", line 1
#     pip install pywhatkit
#               ^
# SyntaxError: invalid syntax
