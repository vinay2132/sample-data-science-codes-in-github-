# %% [markdown]
# # Importing the libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from  google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Bank_Predictions.csv")
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %% [markdown]
# # ------ Part-1: Data preprocessing ----------
#
# # Encoding categorical data

# %%
from enum import auto
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categories = 'auto')
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %% [markdown]
# # ------- Part-2: Build the ANN --------
#
# # import keras library and packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # Initializing the ANN

# %%
classifier = Sequential()

# %% [markdown]
# You might use the following parameters: activation: 'relu' and/or 'sigmoid',optimization function is 'adam', loss function is 'binary_crossentropy',number ofepochs is 100, samples per epoch are 10)

# %%
from sklearn.neural_network import MLPRegressor
nn_scikit = MLPRegressor(hidden_layer_sizes=(16, 8),
                          activation='relu',
                          solver='adam',
                          learning_rate_init=0.001,
                          random_state=42, max_iter=2000)
nn_scikit.fit(X_train, y_train)
predictions = nn_scikit.predict(X_test)
print(predictions)
print(np.mean((y_test - predictions) ** 2))
# Out:
# [0.5464716  0.13358685 0.35699915 ... 0.62210601 0.32296947 0.31213105]
# 0.2835476895902401

# %% [markdown]
# Adding the input layer and the first hidden layer

# %%
classifier.add(Dense(units=6, activation='relu', input_dim=X.shape[1]))

# %% [markdown]
# Adding the second hidden layer

# %%
classifier.add(Dense(units=6, kernel_initializer='uniform', activation='relu'))

# %% [markdown]
# Adding the output layer

# %%
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# %% [markdown]
# Compiling the ANN

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Fitting the ANN to the training set

# %%
classifier.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.5260 - accuracy: 0.7960
# Epoch 2/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4307 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.3732 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3377 - accuracy: 0.7960
# Epoch 5/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3213 - accuracy: 0.7960
# Epoch 6/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3120 - accuracy: 0.7960
# Epoch 7/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3084 - accuracy: 0.7960
# Epoch 8/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3024 - accuracy: 0.7960
# Epoch 9/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2998 - accuracy: 0.7960
# Epoch 10/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2947 - accuracy: 0.7960
# Epoch 11/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2801 - accuracy: 0.8041
# Epoch 12/100
# 800/800 [==============================] - 5s 7ms/step - loss: 0.2670 - accuracy: 0.8209
# Epoch 13/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2560 - accuracy: 0.8371
# Epoch 14/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2426 - accuracy: 0.8491
# Epoch 15/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2390 - accuracy: 0.8530
# Epoch 16/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.2363 - accuracy: 0.8566
# Epoch 17/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2349 - accuracy: 0.8575
# Epoch 18/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2339 - accuracy: 0.8585
# Epoch 19/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.2351 - accuracy: 0.8608
# Epoch 20/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2032 - accuracy: 0.8923
# Epoch 21/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.1342 - accuracy: 0.9582
# Epoch 22/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0832 - accuracy: 0.9819
# Epoch 23/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0661 - accuracy: 0.9852
# Epoch 24/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0586 - accuracy: 0.9861
# Epoch 25/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0549 - accuracy: 0.9862
# Epoch 26/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0531 - accuracy: 0.9862
# Epoch 27/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0600 - accuracy: 0.9834
# Epoch 28/100
# 800/800 [==============================] - 5s 7ms/step - loss: 0.0696 - accuracy: 0.9776
# Epoch 29/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0457 - accuracy: 0.9891
# Epoch 30/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0351 - accuracy: 0.9923
# Epoch 31/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0324 - accuracy: 0.9930
# Epoch 32/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0316 - accuracy: 0.9930
# Epoch 33/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0313 - accuracy: 0.9930
# Epoch 34/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0311 - accuracy: 0.9930
# Epoch 35/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0309 - accuracy: 0.9930
# Epoch 36/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0309 - accuracy: 0.9930
# Epoch 37/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 38/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 39/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 40/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 41/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0308 - accuracy: 0.9930
# Epoch 42/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0317 - accuracy: 0.9924
# Epoch 43/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0310 - accuracy: 0.9929
# Epoch 44/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0307 - accuracy: 0.9930
# Epoch 45/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0307 - accuracy: 0.9930
# Epoch 46/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0526 - accuracy: 0.9861
# Epoch 47/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0684 - accuracy: 0.9786
# Epoch 48/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0321 - accuracy: 0.9916
# Epoch 49/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0207 - accuracy: 0.9959
# Epoch 50/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0176 - accuracy: 0.9966
# Epoch 51/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0162 - accuracy: 0.9969
# Epoch 52/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0157 - accuracy: 0.9971
# Epoch 53/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0151 - accuracy: 0.9973
# Epoch 54/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0149 - accuracy: 0.9973
# Epoch 55/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0148 - accuracy: 0.9973
# Epoch 56/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0148 - accuracy: 0.9973
# Epoch 57/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0147 - accuracy: 0.9973
# Epoch 58/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0226 - accuracy: 0.9935
# Epoch 59/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0212 - accuracy: 0.9942
# Epoch 60/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0115 - accuracy: 0.9977
# Epoch 61/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0099 - accuracy: 0.9984
# Epoch 62/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0098 - accuracy: 0.9984
# Epoch 63/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0097 - accuracy: 0.9984
# Epoch 64/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0097 - accuracy: 0.9984
# Epoch 65/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0096 - accuracy: 0.9984
# Epoch 66/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0096 - accuracy: 0.9984
# Epoch 67/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0096 - accuracy: 0.9984
# Epoch 68/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0096 - accuracy: 0.9984
# Epoch 69/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 70/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 71/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 72/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 73/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 74/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 75/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 76/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 77/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 78/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 79/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 80/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 81/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 82/100
# 800/800 [==============================] - 6s 7ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 83/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 84/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 85/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 86/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 87/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 88/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 89/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 90/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 91/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 92/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 93/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 94/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 95/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 96/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 97/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 98/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 99/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.0095 - accuracy: 0.9984
# Epoch 100/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.0095 - accuracy: 0.9984

# %% [markdown]
#  Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 1s 6ms/step

# %% [markdown]
# Making the confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1595,    0],
#        [ 405,    0]])
