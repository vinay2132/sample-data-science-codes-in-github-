# %%
from sympy import Symbol, diff, solve

xy = Symbol('xy')
f = 6*xy**2 + xy + 6*xy**2
critical_points = solve([diff(f, xy), diff(f, xy, 2)], xy)
print(critical_points)
# print("The critical points of f are:")
# for point in critical_points:
#   print(point)
# Out:
# []

# %%
from sympy import Symbol, diff, solve 
xy=Symbol('xy')
f = 6*x**2+x*y+6*y**2
critical_points = solve([diff(f, xy), diff(f, xy, 2)], xy)
for point in critical_points:
  print(point,'aa')
# Out:
# point

# %%
from sympy import Symbol, diff, solve

xy = Symbol('xy')
f = 6*xy**2 + xy + 6*xy**2
critical_points = solve([diff(f, xy), diff(f, xy, 2)], xy)

print("The critical points of f are:")
for point in critical_points:
    print(point)
# Out:
# The critical points of f are:
