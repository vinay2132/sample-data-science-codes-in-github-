# %%
x = 2

y = 3 * x

x = 4

print(x,y)
# Out:
# 4 6

# %%
def printwhat(numberList):    
  for num in numberList:
    if num % 2 == 0:  
      print(num)

# %%
def sum(numbers):
    total = 0
    for x in numbers:
        if x % 2 == 0:
          print(x) 
print(sum((1,2,3,4,5,6,7,8,9,0)))
# Out:
# 2
# 4
# 6
# 8
# 0
# None

# %%
two = 3

six = two plus two
# Out:
#   File "<ipython-input-13-cfdbf8616da7>", line 3
#     six = two plus two
#               ^
# SyntaxError: invalid syntax

# %%
4 = 2 + 2
# Out:
#   File "<ipython-input-14-4c8b769209ad>", line 1
#     4 = 2 + 2
#     ^
# SyntaxError: cannot assign to literal

# %%
ListOfItems = ['car', 'boat', 'house', 'furniture', 'tractor']

count = 0 # initialize variable

for item in ListOfItems:

        count = count + 1

print(count)
# Out:
# 5

# %%
n = 0
if n <0:
  print('n is negative')
elif n >0:   
  print('n is positive')
