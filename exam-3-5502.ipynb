# %%
myDict = {'love': 0.9, 'awesome': 0.8, 'cool': 0.5, 'good': 0.4, 'okay': 0.2, 'bad': -0.4, 'terrible': -0.6, 'disgusting': -0.7, 'hate': -0.9}

def main_sentiment_analysis(comment):
    words = comment.split()
    total_happiness = 0
    for word in words:
        if word in myDict:
            total_happiness += myDict[word]
    avg_happiness = total_happiness / len(words)
    return avg_happiness

# %%
comment = "I love this product! It's awesome!"
print(main_sentiment_analysis(comment))
# Out:
# 0.15

# %%
wordlist = comment.split(" ")
print(wordlist)
print(main_sentiment_analysis(comment))
# Out:
# ['I', 'love', 'this', 'product!', "It's", 'awesome!']
# 0.15

# %%
total_happiness = 0
for word in wordlist:
    if word in myDict:
        total_happiness += myDict[word]
print(total_happiness)
print(main_sentiment_analysis(comment))
# Out:
# 0.9
# 0.15

# %%
avg_happiness = total_happiness / len(wordlist)
rounded_avg_happiness = round(avg_happiness, 3)
print(rounded_avg_happiness)
# Out:
# 0.15

# %%
comment_a = "Their new shake is terrible - I thought it was good at first but then it left a disgusting taste in my mouth"
comment_b = "Spiderman 2 was awesome for a sequel. I love the cool character development in it"
comment_c = "If there is one thing I hate more than the bad puns in this movie, it is the terrible acting"
comment_d = "ah, that was a cool movie, it wasn’t groundbreaking, but I had a good time"

print(main_sentiment_analysis(comment_a))
print(main_sentiment_analysis(comment_b))
print(main_sentiment_analysis(comment_c))
print(main_sentiment_analysis(comment_d))
# Out:
# -0.03913043478260869
# 0.14666666666666667
# -0.095
# 0.060000000000000005
